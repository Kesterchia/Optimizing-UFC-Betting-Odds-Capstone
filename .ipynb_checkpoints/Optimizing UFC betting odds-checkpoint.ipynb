# %% [markdown]
# <img src="https://github.com/Kesterchia/Optimizing-UFC-Betting-Odds/blob/main/Pictures/Fight-image.jpg?raw=True" width="500" height="500">

# %% [markdown]
# # Source:
# https://www.kaggle.com/mdabbert/ultimate-ufc-dataset?select=ufc-master.csv
#
# ## Context:
#
# This dataset is a merger of a few datasets on Ultimate Fighting Championship (UFC) fights on Kaggle, compiled by Kaggle user Mdabbert (https://www.kaggle.com/mdabbert).
#
# ## Content:
#
# This dataset includes:
#
# Rajeev Warrier's excellent dataset (https://www.kaggle.com/rajeevw/ufcdata). This dataset makes up much of the data. It contains data for every UFC bout. The 'red fighter' and 'blue fighter' are improperly recorded prior to around 2010, so that data has been excluded.
#
# Mdabbert's odds dataset (https://www.kaggle.com/mdabbert/ufc-fights-2010-2020-with-betting-odds). This contains gambling odds for each fight.
#
# Mart Jürisoo's Rankings dataset (https://www.kaggle.com/martj42/ufc-rankings). Includes a history of UFC fighter rankings.
#
# There are 108 columns of data.
#
# ## Column descriptions:
# R_fighter, B_fighter: Fighter names
#
# R_odds, B_odds: The American odds that the fighter will win. Usually scraped from bestfightodds.com
#
# R_ev, B_ev: The profit on a 100 credit winning bet
#
# date: The date of the fight
#
# location: The location of the fight
#
# country: The country the fight occurs in
#
# Winner: The winner of the fight [Red, Blue, or Draw]
#
# title_bout: Was this a title bout?
#
# weight_class: The weight class of the bout
#
# gender: Gender of the combatants
#
# no_of_rounds: The number of rounds in the fight
#
# B_current_lose_streak, R_current_lose_streak: Current losing streak
#
# B_current_win_streak, R_current_win_streak: Current winning streak
#
# B_draw, R_draw: Number of draws
#
# B_avg_SIG_STR_landed, R_avg_SIG_STR_landed : Significant Strikes Landed per minute
#
# B_avg_SIG_STR_pct, R_avg_SIG_STR_pct: Significant Striking Accuracy
#
# B_avg_SUB_ATT, R_avg_SUB_ATT: Average Submissions Attempted per 15 Minutes
#
# B_avg_TD_landed, R_avg_TD_landed: Average takedowns landed per 15 minutes
#
# B_avg_TD_pct, R_avg_TD_pct: Takedown accuracy
#
# B_longest_win_streak, R_longest_win_streak: Longest winning streak
#
# B_losses, R_losses: Total number of losses
#
# B_total_rounds_fought, R_total_rounds_fought: Total rounds fought
#
# B_total_title_bouts, R_total_title_bouts: Total number of title bouts
#
# B_win_by_Decision_Majority, R_win_by_Decision_Majority: Wins by Majority Decision
#
# B_win_by_Decision_Split, R_win_by_Decision_Split: Wins by Split Decision
#
# B_win_by_Decision_Unanimous, R_win_by_Decision_Unanimous: Wins by Unanimous Decision
#
# B_win_by_KO/TKO, R_win_by_KO/TKO: Wins by KO/TKO
#
# B_win_by_Submission, R_win_by_Submission: Wins by Submission
#
# B_win_by_TKO_Doctor_Stoppage, R_win_by_TKO_Doctor_Stoppage: Wins by Doctor Stoppage
#
# B_wins, R_wins: Total career wins
#
# B_Stance, R_stance: Fighter stance
#
# B_Height_cms, R_Height_cms: Fighter height in cms
#
# B_Reach_cms, R_Reach_cms: Fighter reach in cms
#
# B_Weight_lbs, R_Weight_lbs: Fighter weight in pounds
#
# B_age, R_age: Fighter age
#
# lose_streak_dif: (Blue lose streak) - (Red lose streak) winstreakdif: (Blue win streak) - (Red win streak)
#
# longest_win_streak_dif: (Blue longest win streak) - (Red longest win streak)
#
# win_dif: (Blue wins) - (Red wins)
#
# loss_dif: (Blue losses) - (Red losses)
#
# total_round_dif: (Blue total rounds fought) - (Red total rounds fought)
#
# total_title_bout_dif: (Blue number of title fights) - (Red number of title fights)
#
# ko_dif: (Blue wins by KO/TKO) - (Red wins by KO/TKO)
#
# sub_dif: (Blue wins by submission) - (Red wins by submission)
#
# height_dif: (Blue height) - (Red height) in cms
#
# reach_dif: (Blue reach) - (Red reach) in cms
#
# age_dif: (Blue age) - (Red age)
#
# sig_str_dif: (Blue sig strikes per minute) - (Red sig strikes per minute)
#
# avg_sub_att_dif: (Blue submission attempts) - (Red submission attempts)
#
# avg_td_dif: (Blue TD attempts) - (Red TD attempts)
#
# empty_arena: Did this fight occur in an empty arena? (1,0)
#
# constant_1: The number 1
#
# B_match_weightclass_rank, R_match_weightclass_rank: Rank in the weightclass this bout takes place in
#
# R_Women's Flyweight_rank, B_Women's Flyweight_rank: Rank in the Women's Flyweight Division
#
# B_Women's Featherweight_rank, 'RWomen's Featherweightrank: Rank in the Women's Featherweight Division BWomen's
# Strawweightrank, 'R_Women's Strawweight_rank: Rank in the Women's Strawweight Division
#
# B_Women's Bantamweight_rank, R_Women's Bantamweight_rank: Rank in the Women's Bantamweight Division
#
# B_Heavyweight_rank, R_Heavyweight_rank: Heavyweight rank
#
# B_Light Heavyweight_rank, R_Light Heavyweight rank: Light Heavyweight rank
#
# B_Middleweight_rank, R_Middleweight_rank: Middleweight rank
#
# B_Welterweight_rank, R_Welterweight_rank: Welterweight rank
#
# B_Lightweight_rank, R_Lightweight_rank: Lightweight rank
#
# B_Featherweight_rank, R_Featherweight_rank: Featherweight rank
#
# B_Bantamweight_rank, R_Bantamweight_rank: Bantamweight rank
#
# B_Flyweight_rank, R_Flyweight_rank: Flyweight rank
#
# B_Pound-for-Pound_rank, R_Pound-for-Pound_rank: Pound-for-Pound rank
#
# better_rank: Who has the better rank (Red, Blue, neither)
#
# finish: How the fight finished
#
# finish_details: More details about the finish if available.
#
# finish_round: The round the fight ended
#
# finish_round_time: Time in the round of the finish
#
# total_fight_time_secs: Total time of the fight in seconds

# %% [markdown]
# # 1: Importing libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

from pandas_profiling import ProfileReport

# %%
#Import in the dataset
df = pd.read_csv('./Data/ufc-master.csv')

df.head()
# Out:
#               R_fighter         B_fighter  R_odds  B_odds        R_ev  \
# 0   Deiveson Figueiredo        Alex Perez    -286     225   34.965035
# 1  Valentina Shevchenko     Jennifer Maia   -1667     850    5.998800
# 2            Mike Perry         Tim Means    -150     120   66.666667
# 3     Katlyn Chookagian  Cynthia Calvillo     205    -265  205.000000
# 4          Mauricio Rua        Paul Craig     150    -190  150.000000
#
#          B_ev        date                location country Winner  ...  \
# 0  225.000000  11/21/2020  Las Vegas, Nevada, USA     USA    Red  ...
# 1  850.000000  11/21/2020  Las Vegas, Nevada, USA     USA    Red  ...
# 2  120.000000  11/21/2020  Las Vegas, Nevada, USA     USA   Blue  ...
# 3   37.735849  11/21/2020  Las Vegas, Nevada, USA     USA    Red  ...
# 4   52.631579  11/21/2020  Las Vegas, Nevada, USA     USA   Blue  ...
#
#    R_td_attempted_bout B_td_attempted_bout R_td_pct_bout  B_td_pct_bout  \
# 0                  NaN                 NaN           NaN            NaN
# 1                  NaN                 NaN           NaN            NaN
# 2                  NaN                 NaN           NaN            NaN
# 3                  NaN                 NaN           NaN            NaN
# 4                  NaN                 NaN           NaN            NaN
#
#    R_sub_attempts_bout  B_sub_attempts_bout  R_pass_bout  B_pass_bout  \
# 0                  NaN                  NaN          NaN          NaN
# 1                  NaN                  NaN          NaN          NaN
# 2                  NaN                  NaN          NaN          NaN
# 3                  NaN                  NaN          NaN          NaN
# 4                  NaN                  NaN          NaN          NaN
#
#    R_rev_bout  B_rev_bout
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 137 columns]

# %% [markdown]
# # 2: Data cleaning:

# %%
#See some quick info:
df.info(max_cols = 200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4485 entries, 0 to 4484
# Data columns (total 137 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   R_fighter                     4485 non-null   object
#  1   B_fighter                     4485 non-null   object
#  2   R_odds                        4485 non-null   int64
#  3   B_odds                        4485 non-null   int64
#  4   R_ev                          4485 non-null   float64
#  5   B_ev                          4485 non-null   float64
#  6   date                          4485 non-null   object
#  7   location                      4485 non-null   object
#  8   country                       4485 non-null   object
#  9   Winner                        4485 non-null   object
#  10  title_bout                    4485 non-null   bool
#  11  weight_class                  4485 non-null   object
#  12  gender                        4485 non-null   object
#  13  no_of_rounds                  4485 non-null   int64
#  14  B_current_lose_streak         4485 non-null   int64
#  15  B_current_win_streak          4485 non-null   int64
#  16  B_draw                        4485 non-null   int64
#  17  B_avg_SIG_STR_landed          3555 non-null   float64
#  18  B_avg_SIG_STR_pct             3720 non-null   float64
#  19  B_avg_SUB_ATT                 3653 non-null   float64
#  20  B_avg_TD_landed               3652 non-null   float64
#  21  B_avg_TD_pct                  3643 non-null   float64
#  22  B_longest_win_streak          4485 non-null   int64
#  23  B_losses                      4485 non-null   int64
#  24  B_total_rounds_fought         4485 non-null   int64
#  25  B_total_title_bouts           4485 non-null   int64
#  26  B_win_by_Decision_Majority    4485 non-null   int64
#  27  B_win_by_Decision_Split       4485 non-null   int64
#  28  B_win_by_Decision_Unanimous   4485 non-null   int64
#  29  B_win_by_KO/TKO               4485 non-null   int64
#  30  B_win_by_Submission           4485 non-null   int64
#  31  B_win_by_TKO_Doctor_Stoppage  4485 non-null   int64
#  32  B_wins                        4485 non-null   int64
#  33  B_Stance                      4485 non-null   object
#  34  B_Height_cms                  4485 non-null   float64
#  35  B_Reach_cms                   4485 non-null   float64
#  36  B_Weight_lbs                  4485 non-null   int64
#  37  R_current_lose_streak         4485 non-null   int64
#  38  R_current_win_streak          4485 non-null   int64
#  39  R_draw                        4485 non-null   int64
#  40  R_avg_SIG_STR_landed          4030 non-null   float64
#  41  R_avg_SIG_STR_pct             4128 non-null   float64
#  42  R_avg_SUB_ATT                 4128 non-null   float64
#  43  R_avg_TD_landed               4128 non-null   float64
#  44  R_avg_TD_pct                  4118 non-null   float64
#  45  R_longest_win_streak          4485 non-null   int64
#  46  R_losses                      4485 non-null   int64
#  47  R_total_rounds_fought         4485 non-null   int64
#  48  R_total_title_bouts           4485 non-null   int64
#  49  R_win_by_Decision_Majority    4485 non-null   int64
#  50  R_win_by_Decision_Split       4485 non-null   int64
#  51  R_win_by_Decision_Unanimous   4485 non-null   int64
#  52  R_win_by_KO/TKO               4485 non-null   int64
#  53  R_win_by_Submission           4485 non-null   int64
#  54  R_win_by_TKO_Doctor_Stoppage  4485 non-null   int64
#  55  R_wins                        4485 non-null   int64
#  56  R_Stance                      4485 non-null   object
#  57  R_Height_cms                  4485 non-null   float64
#  58  R_Reach_cms                   4485 non-null   float64
#  59  R_Weight_lbs                  4485 non-null   int64
#  60  R_age                         4485 non-null   int64
#  61  B_age                         4485 non-null   int64
#  62  lose_streak_dif               4485 non-null   int64
#  63  win_streak_dif                4485 non-null   int64
#  64  longest_win_streak_dif        4485 non-null   int64
#  65  win_dif                       4485 non-null   int64
#  66  loss_dif                      4485 non-null   int64
#  67  total_round_dif               4485 non-null   int64
#  68  total_title_bout_dif          4485 non-null   int64
#  69  ko_dif                        4485 non-null   int64
#  70  sub_dif                       4485 non-null   int64
#  71  height_dif                    4485 non-null   float64
#  72  reach_dif                     4485 non-null   float64
#  73  age_dif                       4485 non-null   int64
#  74  sig_str_dif                   4485 non-null   float64
#  75  avg_sub_att_dif               4485 non-null   float64
#  76  avg_td_dif                    4485 non-null   float64
#  77  empty_arena                   4485 non-null   int64
#  78  constant_1                    4485 non-null   int64
#  79  B_match_weightclass_rank      794 non-null    float64
#  80  R_match_weightclass_rank      1211 non-null   float64
#  81  R_Women's Flyweight_rank      45 non-null     float64
#  82  R_Women's Featherweight_rank  6 non-null      float64
#  83  R_Women's Strawweight_rank    95 non-null     float64
#  84  R_Women's Bantamweight_rank   109 non-null    float64
#  85  R_Heavyweight_rank            131 non-null    float64
#  86  R_Light Heavyweight_rank      129 non-null    float64
#  87  R_Middleweight_rank           119 non-null    float64
#  88  R_Welterweight_rank           130 non-null    float64
#  89  R_Lightweight_rank            126 non-null    float64
#  90  R_Featherweight_rank          124 non-null    float64
#  91  R_Bantamweight_rank           125 non-null    float64
#  92  R_Flyweight_rank              132 non-null    float64
#  93  R_Pound-for-Pound_rank        148 non-null    float64
#  94  B_Women's Flyweight_rank      32 non-null     float64
#  95  B_Women's Featherweight_rank  0 non-null      float64
#  96  B_Women's Strawweight_rank    54 non-null     float64
#  97  B_Women's Bantamweight_rank   74 non-null     float64
#  98  B_Heavyweight_rank            100 non-null    float64
#  99  B_Light Heavyweight_rank      86 non-null     float64
#  100 B_Middleweight_rank           89 non-null     float64
#  101 B_Welterweight_rank           81 non-null     float64
#  102 B_Lightweight_rank            81 non-null     float64
#  103 B_Featherweight_rank          83 non-null     float64
#  104 B_Bantamweight_rank           78 non-null     float64
#  105 B_Flyweight_rank              89 non-null     float64
#  106 B_Pound-for-Pound_rank        28 non-null     float64
#  107 better_rank                   4485 non-null   object
#  108 finish                        4118 non-null   object
#  109 finish_details                2014 non-null   object
#  110 finish_round                  4099 non-null   float64
#  111 finish_round_time             4099 non-null   object
#  112 total_fight_time_secs         4099 non-null   float64
#  113 R_kd_bout                     2772 non-null   float64
#  114 B_kd_bout                     2772 non-null   float64
#  115 R_sig_str_landed_bout         2772 non-null   float64
#  116 B_sig_str_landed_bout         2772 non-null   float64
#  117 R_sig_str_attempted_bout      2772 non-null   float64
#  118 B_sig_str_attempted_bout      2772 non-null   float64
#  119 R_sig_str_pct_bout            2772 non-null   float64
#  120 B_sig_str_pct_bout            2772 non-null   float64
#  121 R_tot_str_landed_bout         2772 non-null   float64
#  122 B_tot_str_landed_bout         2772 non-null   float64
#  123 R_tot_str_attempted_bout      2772 non-null   float64
#  124 B_tot_str_attempted_bout      2772 non-null   float64
#  125 R_td_landed_bout              2772 non-null   float64
#  126 B_td_landed_bout              2772 non-null   float64
#  127 R_td_attempted_bout           2772 non-null   float64
#  128 B_td_attempted_bout           2772 non-null   float64
#  129 R_td_pct_bout                 2772 non-null   float64
#  130 B_td_pct_bout                 2772 non-null   float64
#  131 R_sub_attempts_bout           2772 non-null   float64
#  132 B_sub_attempts_bout           2772 non-null   float64
#  133 R_pass_bout                   2772 non-null   float64
#  134 B_pass_bout                   2772 non-null   float64
#  135 R_rev_bout                    2772 non-null   float64
#  136 B_rev_bout                    2772 non-null   float64
# dtypes: bool(1), float64(75), int64(47), object(14)
# memory usage: 4.7+ MB

# %% [markdown]
# The columns such as 'B_Women's Flyweight_rank', 'B_Women's Strawweight_rank' are irrelevant, as we already have the weight class and respective fighter rank as columns of their own. Therefore these columns will be dropped.

# %%
df = df.drop(labels = df.columns[81:107],
             axis = 1)
df.info(max_cols = 150)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4485 entries, 0 to 4484
# Data columns (total 111 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   R_fighter                     4485 non-null   object
#  1   B_fighter                     4485 non-null   object
#  2   R_odds                        4485 non-null   int64
#  3   B_odds                        4485 non-null   int64
#  4   R_ev                          4485 non-null   float64
#  5   B_ev                          4485 non-null   float64
#  6   date                          4485 non-null   object
#  7   location                      4485 non-null   object
#  8   country                       4485 non-null   object
#  9   Winner                        4485 non-null   object
#  10  title_bout                    4485 non-null   bool
#  11  weight_class                  4485 non-null   object
#  12  gender                        4485 non-null   object
#  13  no_of_rounds                  4485 non-null   int64
#  14  B_current_lose_streak         4485 non-null   int64
#  15  B_current_win_streak          4485 non-null   int64
#  16  B_draw                        4485 non-null   int64
#  17  B_avg_SIG_STR_landed          3555 non-null   float64
#  18  B_avg_SIG_STR_pct             3720 non-null   float64
#  19  B_avg_SUB_ATT                 3653 non-null   float64
#  20  B_avg_TD_landed               3652 non-null   float64
#  21  B_avg_TD_pct                  3643 non-null   float64
#  22  B_longest_win_streak          4485 non-null   int64
#  23  B_losses                      4485 non-null   int64
#  24  B_total_rounds_fought         4485 non-null   int64
#  25  B_total_title_bouts           4485 non-null   int64
#  26  B_win_by_Decision_Majority    4485 non-null   int64
#  27  B_win_by_Decision_Split       4485 non-null   int64
#  28  B_win_by_Decision_Unanimous   4485 non-null   int64
#  29  B_win_by_KO/TKO               4485 non-null   int64
#  30  B_win_by_Submission           4485 non-null   int64
#  31  B_win_by_TKO_Doctor_Stoppage  4485 non-null   int64
#  32  B_wins                        4485 non-null   int64
#  33  B_Stance                      4485 non-null   object
#  34  B_Height_cms                  4485 non-null   float64
#  35  B_Reach_cms                   4485 non-null   float64
#  36  B_Weight_lbs                  4485 non-null   int64
#  37  R_current_lose_streak         4485 non-null   int64
#  38  R_current_win_streak          4485 non-null   int64
#  39  R_draw                        4485 non-null   int64
#  40  R_avg_SIG_STR_landed          4030 non-null   float64
#  41  R_avg_SIG_STR_pct             4128 non-null   float64
#  42  R_avg_SUB_ATT                 4128 non-null   float64
#  43  R_avg_TD_landed               4128 non-null   float64
#  44  R_avg_TD_pct                  4118 non-null   float64
#  45  R_longest_win_streak          4485 non-null   int64
#  46  R_losses                      4485 non-null   int64
#  47  R_total_rounds_fought         4485 non-null   int64
#  48  R_total_title_bouts           4485 non-null   int64
#  49  R_win_by_Decision_Majority    4485 non-null   int64
#  50  R_win_by_Decision_Split       4485 non-null   int64
#  51  R_win_by_Decision_Unanimous   4485 non-null   int64
#  52  R_win_by_KO/TKO               4485 non-null   int64
#  53  R_win_by_Submission           4485 non-null   int64
#  54  R_win_by_TKO_Doctor_Stoppage  4485 non-null   int64
#  55  R_wins                        4485 non-null   int64
#  56  R_Stance                      4485 non-null   object
#  57  R_Height_cms                  4485 non-null   float64
#  58  R_Reach_cms                   4485 non-null   float64
#  59  R_Weight_lbs                  4485 non-null   int64
#  60  R_age                         4485 non-null   int64
#  61  B_age                         4485 non-null   int64
#  62  lose_streak_dif               4485 non-null   int64
#  63  win_streak_dif                4485 non-null   int64
#  64  longest_win_streak_dif        4485 non-null   int64
#  65  win_dif                       4485 non-null   int64
#  66  loss_dif                      4485 non-null   int64
#  67  total_round_dif               4485 non-null   int64
#  68  total_title_bout_dif          4485 non-null   int64
#  69  ko_dif                        4485 non-null   int64
#  70  sub_dif                       4485 non-null   int64
#  71  height_dif                    4485 non-null   float64
#  72  reach_dif                     4485 non-null   float64
#  73  age_dif                       4485 non-null   int64
#  74  sig_str_dif                   4485 non-null   float64
#  75  avg_sub_att_dif               4485 non-null   float64
#  76  avg_td_dif                    4485 non-null   float64
#  77  empty_arena                   4485 non-null   int64
#  78  constant_1                    4485 non-null   int64
#  79  B_match_weightclass_rank      794 non-null    float64
#  80  R_match_weightclass_rank      1211 non-null   float64
#  81  better_rank                   4485 non-null   object
#  82  finish                        4118 non-null   object
#  83  finish_details                2014 non-null   object
#  84  finish_round                  4099 non-null   float64
#  85  finish_round_time             4099 non-null   object
#  86  total_fight_time_secs         4099 non-null   float64
#  87  R_kd_bout                     2772 non-null   float64
#  88  B_kd_bout                     2772 non-null   float64
#  89  R_sig_str_landed_bout         2772 non-null   float64
#  90  B_sig_str_landed_bout         2772 non-null   float64
#  91  R_sig_str_attempted_bout      2772 non-null   float64
#  92  B_sig_str_attempted_bout      2772 non-null   float64
#  93  R_sig_str_pct_bout            2772 non-null   float64
#  94  B_sig_str_pct_bout            2772 non-null   float64
#  95  R_tot_str_landed_bout         2772 non-null   float64
#  96  B_tot_str_landed_bout         2772 non-null   float64
#  97  R_tot_str_attempted_bout      2772 non-null   float64
#  98  B_tot_str_attempted_bout      2772 non-null   float64
#  99  R_td_landed_bout              2772 non-null   float64
#  100 B_td_landed_bout              2772 non-null   float64
#  101 R_td_attempted_bout           2772 non-null   float64
#  102 B_td_attempted_bout           2772 non-null   float64
#  103 R_td_pct_bout                 2772 non-null   float64
#  104 B_td_pct_bout                 2772 non-null   float64
#  105 R_sub_attempts_bout           2772 non-null   float64
#  106 B_sub_attempts_bout           2772 non-null   float64
#  107 R_pass_bout                   2772 non-null   float64
#  108 B_pass_bout                   2772 non-null   float64
#  109 R_rev_bout                    2772 non-null   float64
#  110 B_rev_bout                    2772 non-null   float64
# dtypes: bool(1), float64(49), int64(47), object(14)
# memory usage: 3.8+ MB

# %% [markdown]
# Now we store our variables in X and y:

# %%
y = df['Winner'].copy()
X = df.drop(labels = 'Winner', axis = 1).copy()

# %% [markdown]
# ## 2.1: Imputing and scaling variables:
#
# We check how many variables have null values:

# %%
nullcols = df.columns[df.isnull().any(axis=0)]

len(nullcols)
# Out:
# 41

# %% [markdown]
# There are too many columns to have a different imputing strategy for each, so we will use sklearn's iterative imputer to impute the missing values. It goes through each column and returns predictions for missing values based on all other columns. After going through all variables, it repeats the cycle for a number of iterations.
#
# The default strategy for the iterative imputer is to use a Bayesian Ridge Regression, an alternative to OLS.
#
# Documentation: https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html#sklearn.impute.IterativeImputer

# %%
X_numeric = X.select_dtypes(exclude = 'object').copy()
X_cat = X.select_dtypes(include = 'object').copy()

# %% [markdown]
# ### Impute numerical variables first in X_numeric:

# %%
# %%time
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(estimator = None, #Default bayesian ridge
                           max_iter = 100)

#Impute values:
X_numeric_imputed = pd.DataFrame(data = imputer.fit_transform(X_numeric),
                                 columns = X_numeric.columns)
# Out:
# Wall time: 1min 29s
# D:\Tools\Anaconda\lib\site-packages\sklearn\impute\_iterative.py:669: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %% [markdown]
# ### Scale the numerical variables:

# %%
X_numeric_imputed.shape
# Out:
# (4485, 97)

# %%
#Initialize an iterator:
import itertools

iterator = itertools.product(range(10), range(10))

# %%
#Before scaling we first check the distribution of the variables:

fig, ax = plt.subplots(nrows = 10,
                       ncols = 10,
                      figsize = (30,30))


for i in range(97):
    axis = next(iterator)
    sns.distplot(X_numeric_imputed.iloc[:,i],
                 ax = ax[axis[0]][axis[1]]
                )
# Out:
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# D:\Tools\Anaconda\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Alot of the data definitely seems skewed, so we will use a robust scaler instead of the standard scaler. This just means more robust measures like medians/inter-quartile ranges will be used instead of the typical mean/standard deviation.

# %%
from sklearn.preprocessing import RobustScaler

robustscaler = RobustScaler()

#Scale the data:
X_numeric_imputed_scaled = pd.DataFrame(robustscaler.fit_transform(X_numeric_imputed),
                                        columns = X_numeric.columns)

#Check a few rows of the scaled data:
X_numeric_imputed_scaled.head()
# Out:
#      R_odds    B_odds      R_ev      B_ev  title_bout  no_of_rounds  \
# 0 -0.348718  0.256757 -0.346320  0.608840         0.0           2.0
# 1 -3.889744  1.945946 -0.662758  4.614365         0.0           0.0
# 2  0.000000 -0.027027  0.000000 -0.064088         0.0           0.0
# 3  0.910256 -1.067568  1.511204 -0.591306         0.0           0.0
# 4  0.769231 -0.864865  0.910364 -0.495842         0.0           0.0
#
#    B_current_lose_streak  B_current_win_streak  B_draw  B_avg_SIG_STR_landed  \
# 0                    0.0                   3.0     0.0             -1.242549
# 1                    0.0                   1.0     0.0             -1.272984
# 2                    0.0                   1.0     0.0             -1.230375
# 3                    0.0                   3.0     1.0             -1.266390
# 4                    0.0                   2.0     1.0             -1.363274
#
#    ...  R_td_attempted_bout  B_td_attempted_bout  R_td_pct_bout  \
# 0  ...            -0.269232             0.420240       0.260386
# 1  ...             0.395672            -0.359117       0.232625
# 2  ...            -0.193840            -0.216799      -0.156587
# 3  ...             0.038745             0.702609      -0.208748
# 4  ...            -0.542538             0.960724      -0.305276
#
#    B_td_pct_bout  R_sub_attempts_bout  B_sub_attempts_bout  R_pass_bout  \
# 0       0.020385             1.209339            -0.012662    -0.032230
# 1      -0.491021             0.231308            -0.391477     0.620892
# 2      -0.266133             0.080513             0.257625    -0.212486
# 3       0.264560             0.671821             0.118327    -0.019552
# 4       0.742820            -0.276830             3.856616    -0.124437
#
#    B_pass_bout  R_rev_bout  B_rev_bout
# 0     0.059223    0.129574    1.616657
# 1    -0.690674    0.046863    0.713819
# 2    -0.264196    0.762803   -0.358307
# 3     0.184712    1.071783    0.745946
# 4     2.390433    3.148376    2.313111
#
# [5 rows x 97 columns]

# %% [markdown]
# ### Impute time-related variables in X_cat:

# %%
#Our finishing time in round is stored as an object, the wrong datatype:

X_cat.loc[:,'finish_round_time']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 4480    0:44
# 4481    2:01
# 4482    0:47
# 4483    5:00
# 4484    5:00
# Name: finish_round_time, Length: 4485, dtype: object

# %%
#First we have to convert it to hh:mm:ss format:

X_cat.loc[:,'finish_round_time'] = '00:0' + X_cat.loc[:,'finish_round_time']
X_cat.loc[:,'finish_round_time']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 4480    00:00:44
# 4481    00:02:01
# 4482    00:00:47
# 4483    00:05:00
# 4484    00:05:00
# Name: finish_round_time, Length: 4485, dtype: object

# %%
#Now we can convert it to a timedelta object

X_cat.loc[:,'finish_round_time'] = pd.to_timedelta(X_cat.loc[:,'finish_round_time'])
X_cat.loc[:,'finish_round_time']
# Out:
# 0           NaT
# 1           NaT
# 2           NaT
# 3           NaT
# 4           NaT
#          ...
# 4480   00:00:44
# 4481   00:02:01
# 4482   00:00:47
# 4483   00:05:00
# 4484   00:05:00
# Name: finish_round_time, Length: 4485, dtype: timedelta64[ns]

# %%
#Finally we store it in seconds instead:

X_cat.loc[:,'finish_round_time'] = X_cat.loc[:,'finish_round_time'].dt.seconds
X_cat.loc[:,'finish_round_time'] #Note it becomes stored in float format

# %% [markdown]
# Now we can impute the null values. Before that we should look at how it is distributed:

# %%
#Now we can impute the values. Before that we see how it is distributed:

sns.distplot(X_cat.loc[:,'finish_round_time'])

# %% [markdown]
# Since it's pretty skewed, we should use a robust measure to impute instead (the median).

# %%
from sklearn.impute import SimpleImputer

simple_imputer = SimpleImputer(strategy = 'median')

#Impute values:
X_cat.loc[:,'finish_round_time'] = simple_imputer.fit_transform(X_cat[['finish_round_time']])

#Check for null values:
X_cat['finish_round_time'].isnull().sum()

# %% [markdown]
# ### Impute remaining categorical variables in X_cat:

# %%
#Check which columns still have null values:

X_cat.isnull().any()
# Out:
# R_fighter            False
# B_fighter            False
# date                 False
# location             False
# country              False
# weight_class         False
# gender               False
# B_Stance             False
# R_Stance             False
# better_rank          False
# finish                True
# finish_details        True
# finish_round_time    False
# dtype: bool

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 5))

#Plot for 'finish':

sns.countplot(X_cat['finish'], ax = ax[0])

#Plot for 'finish_details'

sns.countplot(X_cat['finish_details'], ax = ax[1])
ax[1].tick_params(axis = 'x', labelbottom = False) #Hide the bottom labels so it doesn't look too messy

# %% [markdown]
# Using the mode to impute the missing values doesn't seem like an appropriate approach for these two variables, especially 'finish_details'. Therefore we will be conservative and just leave the missing values as they are:

# %%
#Fill in the null values with a simple 'Missing' string:
X_cat.loc[:,'finish'] = X_cat['finish'].fillna(value = 'Missing')
X_cat.loc[:,'finish_details'] = X_cat['finish_details'].fillna(value = 'Missing')

#Ensure there are no remaining null values:
X_cat.isnull().sum()

#Rename the imputed dataframe for clarity:
X_cat_imputed = X_cat

# %% [markdown]
# ### Rejoin our numerical and categorical dataframes:

# %%
cleaned_df = pd.concat([X_cat_imputed, X_numeric_imputed_scaled], axis = 1, join = 'inner')

print('Merged dataframe shape:',cleaned_df.shape)
print('Columns with null values:',cleaned_df.isnull().any().sum())
# Out:
# Merged dataframe shape: (4485, 110)
# Columns with null values: 0

# %%
#See a few rows of our cleaned and scaled data:

cleaned_df.head()
# Out:
#               R_fighter         B_fighter        date                location  \
# 0   Deiveson Figueiredo        Alex Perez  11/21/2020  Las Vegas, Nevada, USA
# 1  Valentina Shevchenko     Jennifer Maia  11/21/2020  Las Vegas, Nevada, USA
# 2            Mike Perry         Tim Means  11/21/2020  Las Vegas, Nevada, USA
# 3     Katlyn Chookagian  Cynthia Calvillo  11/21/2020  Las Vegas, Nevada, USA
# 4          Mauricio Rua        Paul Craig  11/21/2020  Las Vegas, Nevada, USA
#
#   country       weight_class  gender  B_Stance  R_Stance better_rank  ...  \
# 0     USA          Flyweight    MALE  Orthodox  Orthodox         Red  ...
# 1     USA  Women's Flyweight  FEMALE  Orthodox  Southpaw         Red  ...
# 2     USA       Welterweight    MALE  Orthodox  Orthodox     neither  ...
# 3     USA  Women's Flyweight  FEMALE  Orthodox  Orthodox         Red  ...
# 4     USA  Light Heavyweight    MALE  Orthodox  Orthodox         Red  ...
#
#   R_td_attempted_bout B_td_attempted_bout  R_td_pct_bout  B_td_pct_bout  \
# 0           -0.269232            0.420240       0.260386       0.020385
# 1            0.395672           -0.359117       0.232625      -0.491021
# 2           -0.193840           -0.216799      -0.156587      -0.266133
# 3            0.038745            0.702609      -0.208748       0.264560
# 4           -0.542538            0.960724      -0.305276       0.742820
#
#    R_sub_attempts_bout  B_sub_attempts_bout  R_pass_bout  B_pass_bout  \
# 0             1.209339            -0.012662    -0.032230     0.059223
# 1             0.231308            -0.391477     0.620892    -0.690674
# 2             0.080513             0.257625    -0.212486    -0.264196
# 3             0.671821             0.118327    -0.019552     0.184712
# 4            -0.276830             3.856616    -0.124437     2.390433
#
#    R_rev_bout  B_rev_bout
# 0    0.129574    1.616657
# 1    0.046863    0.713819
# 2    0.762803   -0.358307
# 3    1.071783    0.745946
# 4    3.148376    2.313111
#
# [5 rows x 110 columns]
